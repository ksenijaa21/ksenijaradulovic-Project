# %% [markdown]
# # Gaussian filter

# %%
import numpy as np
from scipy import fftpack
import matplotlib.pyplot as plt

# %% [markdown]
# ## Original image upload

# %%
img = plt.imread('C:/Users/enar/Desktop/animal.png')
plt.figure()
plt.imshow(img)

# %% [markdown]
# ## Preparing Gaussian kernel

# %%
# 1-D Gaussian

t = np.linspace(-10, 10, 30)
bump = np.exp(-0.1*t**2)
bump /= np.trapz(bump)

# 2-D Gaussian
kernel = bump[:, np.newaxis] * bump[np.newaxis, :]

# %% [markdown]
# ## Implementing convolution

# %%
kernel_ft = fftpack.fft2(kernel, shape=img.shape[:2], axes=(0, 1))
img_ft = fftpack.fft2(img, axes=(0, 1))
img2_ft = kernel_ft[:, :, np.newaxis] * img_ft
img2 = fftpack.ifft2(img2_ft, axes=(0, 1)).real
img2 = np.clip(img2, 0, 1)
# Out:
# c:\users\enar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x

# %% [markdown]
# ## Blurred Image

# %%
plt.figure()
plt.imshow(img2)

# %% [markdown]
# ## Border fix
# To fix 'wrapped border' effect we can use scipy.signal.fftconvolve

# %%
from scipy import signal

img3 = signal.fftconvolve(img, kernel[:, :, np.newaxis], mode='same')
plt.figure()
plt.imshow(img3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
